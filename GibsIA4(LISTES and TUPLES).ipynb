# %% [markdown]
# # **LISTES and TUPLES**

# %% [markdown]
# Les LUSTES

# %%
liste_1 = [1,4,2,7,35,84]
villes = ['Paris','Berlin','Londres','Bruxelles']
liste_2 = [liste_1, villes]
liste_3 = []

# %% [markdown]
# Les TUPLES // On ne peut les modifier

# %%
tuple = (1,5,6,8,7,4,9,23)

# %% [markdown]
# Les STRING

# %%
Prenom = 'Maditaba Thabitha'

# %% [markdown]
# Les INDEX

# %%
print(villes[0]) #premier element = index 0
print(villes[1]) #second element = index 1
print(villes[-1]) #dernier element = index -1
print(villes[-2]) #Avant dernier element = index -3
# Out:
# Paris
# Berlin
# Bruxelles
# Londres

# %% [markdown]
# Les SLICING : Liste[debut:fin:pas]

# %%
liste_1[0::2]
# Out:
# [1, 2, 35]

# %%
if 'paris' in villes:
  print('oui')
else:
  print('non')
# Out:
# non

# %%
for i in villes:
  print(i)
# Out:
# Paris
# Berlin
# Londres
# Bruxelles

# %%
for index, valeur in enumerate(villes):
  print(index, valeur)
# Out:
# 0 Paris
# 1 Berlin
# 2 Londres
# 3 Bruxelles

# %%
for a, b in zip(villes, liste_1):
  print(a, b)
# Out:
# Paris 1
# Berlin 4
# Londres 2
# Bruxelles 7
