# %%
import numpy as np

# %% [markdown]
# # **BROADCASTING**

# %%
np.random.seed(0)
A = np.random.randint(0, 10, [2,3])
B = np.ones((2,3))

# %%
A
# Out:
# array([[5, 0, 3],
#        [3, 7, 9]])

# %%
B
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
A + B
# Out:
# array([[ 6.,  1.,  4.],
#        [ 4.,  8., 10.]])

# %%
np.random.seed(0)
A1 = np.random.randint(0, 10, [3,3])
B1 = np.ones((1,1))

# %%
A1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2]])

# %%
B1
# Out:
# array([[1.]])

# %%
A1 + B1
# Out:
# array([[ 6.,  1.,  4.],
#        [ 4.,  8., 10.],
#        [ 4.,  6.,  3.]])

# %%
np.random.seed(0)
A2 = np.random.randint(0, 10, [4,1])
B2 = np.ones((1,3))

# %%
A2
# Out:
# array([[5],
#        [0],
#        [3],
#        [3]])

# %%
B2
# Out:
# array([[1., 1., 1.]])

# %%
A2 + B2
# Out:
# array([[6., 6., 6.],
#        [1., 1., 1.],
#        [4., 4., 4.],
#        [4., 4., 4.]])
