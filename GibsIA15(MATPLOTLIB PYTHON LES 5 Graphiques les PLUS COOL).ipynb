# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
#print(x)
#print(y)
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classes

# %% [markdown]
# # **(5) Graphique de Classification avec plt.scatter**

# %%
plt.scatter(x[:,0], x[:,1], c=y, alpha=0.5, s=x[:,2]*100)
plt.xlabel('longueur sepal')
plt.ylabel('largeur sepal')
# Out:
# Text(0, 0.5, 'largeur sepal')

# %% [markdown]
# # **(4) Graphique 3D**

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:,0], x[:,1], x[:,2], c=y)

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)*np.cos(x)

# %%
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %%
Z.shape
# Out:
# (100, 100)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')

# %% [markdown]
# # **(3) Histogramme**

# %%
plt.hist(x[:,0], bins=10)
plt.hist(x[:,1], bins=10)
plt.hist(x[:,2], bins=10)
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <a list of 10 Patch objects>)

# %%
#plt.hist2d(x[:,0],x[:,1])
plt.hist2d(x[:,0],x[:,1], cmap='Blues')
plt.xlabel('longueur sepal')
plt.ylabel('largeur sepal')
plt.colorbar()

# %%
from scipy import misc
face = misc.face(gray=True)
#plt.imshow(face, cmap='gray')
plt.hist(face.ravel(), bins=255)
plt.show()
#type(face)
#face.shape

# %% [markdown]
# # **(2) Contour Plot**

# %%
plt.contour(X, Y, Z, 20, colors='black')

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# # **(1) Imshow**

# %%
plt.imshow(face)

# %%
plt.imshow(np.corrcoef(x.T), cmap='Blues')
plt.colorbar()
plt.show()

# %% [markdown]
# # **Exercice**
# Modifier le code ci-dessous et le transformer un peu; afin d'afficher sur une seule meme figure les different variables que l'on a dans notre datasets de "Iris

# %% [markdown]
# # **Ma reponse**

# %%
datasets = {
    f"experience{i}": x[:,i]
    for i in range(4)
}
#datasets

# %%
#def graphique(datasets):
n = len(datasets)
plt.figure(figsize=(10,555))
plt.imshow(x)
plt.colorbar()
plt.show()
#graphique(datasets)

# %% [markdown]
# # **Correction**

# %%
n = x.shape[1]
plt.figure(figsize=(12, 8))
for i in range(n):
  plt.subplot(n//2, n//2, i+1)
  plt.scatter(x[:, 0], x[:, i], c=y)
  plt.xlabel('0')
  plt.ylabel(i)
  #plt.colorbar(ticks=list(np.unique(y)))
  plt.colorbar()
plt.show()
