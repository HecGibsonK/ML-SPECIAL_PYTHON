# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel('titanic.xls')
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # Новый раздел

# %%
data.shape
# Out:
# (1309, 14)

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.head()
# Out:
#    pclass  survived  ...   body                        home.dest
# 0       1         1  ...    NaN                     St Louis, MO
# 1       1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
data = data.drop(['name', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], axis=1)

# %%
data.head()
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
data.describe()
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %% [markdown]
# # Utilisation de fonction **"fillna"** pour completer une valeur manquante

# %%
data = data.dropna(axis=0)
# data.dropna(axis=0, inplace=True) ## une autre variante
data.shape
# Out:
# (1046, 4)

# %%
data.describe()
# Out:
#             pclass     survived          age
# count  1046.000000  1046.000000  1046.000000
# mean      2.207457     0.408222    29.881135
# std       0.841497     0.491740    14.413500
# min       1.000000     0.000000     0.166700
# 25%       1.000000     0.000000    21.000000
# 50%       2.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
data['pclass'].value_counts()
# Out:
# 3    501
# 1    284
# 2    261
# Name: pclass, dtype: int64

# %%
data['pclass'].value_counts().plot.bar()

# %%
data['age'].hist()

# %%
data.groupby(['sex']).mean()
# Out:
#           pclass  survived        age
# sex
# female  2.048969  0.752577  28.687071
# male    2.300912  0.205167  30.585233

# %%
data.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.962406  37.037594
#        2       0.893204  27.499191
#        3       0.473684  22.185307
# male   1       0.350993  41.029250
#        2       0.145570  30.815401
#        3       0.169054  25.962273

# %% [markdown]
# # **Series et DataFrame**

# %%
data['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1301    45.5000
# 1304    14.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1046, dtype: float64

# %%
data = pd.read_excel('titanic.xls')
data = data.set_index('name')
data['age']
# Out:
# name
# Allen, Miss. Elisabeth Walton                      29.0000
# Allison, Master. Hudson Trevor                      0.9167
# Allison, Miss. Helen Loraine                        2.0000
# Allison, Mr. Hudson Joshua Creighton               30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    25.0000
#                                                     ...
# Zabour, Miss. Hileni                               14.5000
# Zabour, Miss. Thamine                                  NaN
# Zakarian, Mr. Mapriededer                          26.5000
# Zakarian, Mr. Ortin                                27.0000
# Zimmerman, Mr. Leo                                 29.0000
# Name: age, Length: 1309, dtype: float64

# %%
data = pd.read_excel('titanic.xls')
data = data.drop(['name', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], axis=1)

# %%
data['age']
data['age'][0:10]
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# 5    48.0000
# 6    63.0000
# 7    39.0000
# 8    53.0000
# 9    71.0000
# Name: age, dtype: float64

# %%
data['age']<18
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
data[data['age']<18]
# Out:
#       pclass  survived     sex      age
# 1          1         1    male   0.9167
# 2          1         0  female   2.0000
# 53         1         0    male  17.0000
# 54         1         1    male  11.0000
# 55         1         1  female  14.0000
# ...      ...       ...     ...      ...
# 1265       3         0  female  10.0000
# 1275       3         0    male  16.0000
# 1279       3         0  female  14.0000
# 1300       3         1  female  15.0000
# 1304       3         0  female  14.5000
#
# [154 rows x 4 columns]

# %%
data[data['age']<18]['pclass']
# Out:
# 1       1
# 2       1
# 53      1
# 54      1
# 55      1
#        ..
# 1265    3
# 1275    3
# 1279    3
# 1300    3
# 1304    3
# Name: pclass, Length: 154, dtype: int64

# %%
data[data['age']<18]['pclass'].value_counts()
# Out:
# 3    106
# 2     33
# 1     15
# Name: pclass, dtype: int64

# %%
data[data['age']<18].groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.875000  14.125000
#        2       1.000000   8.273150
#        3       0.543478   8.416667
# male   1       0.857143   9.845243
#        2       0.733333   6.222220
#        3       0.233333   9.838888

# %%
data.iloc[0, 0]
# Out:
# 1

# %%
data.iloc[0:2, 0:2]
# Out:
#    pclass  survived
# 0       1         1
# 1       1         1

# %%
data.loc[0:2, ['age']]
# Out:
#        age
# 0  29.0000
# 1   0.9167
# 2   2.0000

# %%
data.loc[0:2, ['age', 'sex']]
# Out:
#        age     sex
# 0  29.0000  female
# 1   0.9167    male
# 2   2.0000  female

# %% [markdown]
# # **Exercice - Feature Engineering**
#
# Modifier la colonne 'age' afin de creer 4 categories:
# *   cat0: <20 ans
# *   cat1: 20-30 ans
# *   cat2: 30-40 ans
# *   cat3: +40 ans

# %% [markdown]
# ## **Ma reponse** (**vraie**)

# %%
Adata = data['age']
Adata[10]
# Out:
# 47.0

# %%
n = len(Adata)
for i in range(0, n):
  if data['age'][i]<=20:
    cat0 = Adata[data['age']<=20]
  if (data['age'][i]>20)&(data['age'][i]<=30):
    cat1 = Adata[(data['age']>20)&(data['age']<=30)]
  if (data['age'][i]>30)&(data['age'][i]<=40):
    cat2 = Adata[(data['age']>30)&(data['age']<=40)]
  if data['age'][i]>40:
    cat3 = Adata[data['age']>40]

# %%
print('les valeurs pour la categorie Cat0 sont: \n', cat0, 'ans')
# Out:
# les valeurs pour la categorie Cat0 sont:
#  1        0.9167
# 2        2.0000
# 11      18.0000
# 27      19.0000
# 53      17.0000
#          ...
# 1278    20.0000
# 1279    14.0000
# 1288    18.0000
# 1300    15.0000
# 1304    14.5000
# Name: age, Length: 248, dtype: float64 ans

# %%
print('les valeurs pour la categorie Cat0 sont: \n', cat1)
# Out:
# les valeurs pour la categorie Cat0 sont:
#  0       29.0
# 3       30.0
# 4       25.0
# 12      24.0
# 13      26.0
#         ...
# 1296    27.0
# 1299    27.0
# 1306    26.5
# 1307    27.0
# 1308    29.0
# Name: age, Length: 361, dtype: float64

# %%
print('les valeurs pour la categorie Cat0 sont: \n', cat2, 'ans')
# Out:
# les valeurs pour la categorie Cat0 sont:
#  7       39.0
# 18      32.0
# 19      36.0
# 20      37.0
# 28      35.0
#         ...
# 1274    31.0
# 1276    31.0
# 1285    32.5
# 1286    38.0
# 1298    36.0
# Name: age, Length: 210, dtype: float64 ans

# %%
print('les valeurs pour la categorie Cat0 sont: \n', cat3, 'ans')
# Out:
# les valeurs pour la categorie Cat0 sont:
#  5       48.0
# 6       63.0
# 8       53.0
# 9       71.0
# 10      47.0
#         ...
# 1264    40.5
# 1272    47.0
# 1287    51.0
# 1290    47.0
# 1301    45.5
# Name: age, Length: 227, dtype: float64 ans

# %% [markdown]
# # **Correction**

# %%
data.loc[data['age']<=20, "age"] = 0
data.loc[(data['age']>20) & (data['age']<=30), "age"] = 1
data.loc[(data['age']>30) & (data['age']<=40), "age"] = 2
data.loc[data['age']>40, "age"] = 3

# %%
data.head()
# Out:
#    pclass  survived     sex  age
# 0       1         1  female  1.0
# 1       1         1    male  0.0
# 2       1         0  female  0.0
# 3       1         0    male  1.0
# 4       1         0  female  1.0

# %%
data['age'].value_counts()
# Out:
# 1.0    361
# 0.0    248
# 3.0    227
# 2.0    210
# Name: age, dtype: int64

# %%
data.groupby(['age']).mean()
# Out:
#        pclass  survived
# age
# 0.0  2.568548  0.459677
# 1.0  2.371191  0.371191
# 2.0  2.109524  0.423810
# 3.0  1.643172  0.396476

# %% [markdown]
# # **Correction (variante II)**
#
# # Avec la fonction '**map**'

# %%
def category_age(age):
  if age <= 20:
    return '<20 ans'
  elif (age > 20) & (age <= 30):
    return '20-30 ans'
  elif (age > 30) & (age <=40):
    return '30-40 ans'
  else:
    return '+40 ans'

# %%
category_age(33)
# Out:
# '30-40 ans'

# %%
data['age'].map(category_age)
# Out:
# 0       <20 ans
# 1       <20 ans
# 2       <20 ans
# 3       <20 ans
# 4       <20 ans
#          ...
# 1304    <20 ans
# 1305    +40 ans
# 1306    <20 ans
# 1307    <20 ans
# 1308    <20 ans
# Name: age, Length: 1309, dtype: object

# %% [markdown]
# # **BONUS**
# map()
#
# replace()
#
# cat.codes()

# %%
data['sex'].map({'male':0, 'female':1})
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sex, Length: 1309, dtype: int64

# %%
data['sex'].replace(['male', 'female'], [0, 1])
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sex, Length: 1309, dtype: int64

# %%
data['sex'].astype('category').cat.codes
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    1
# 1307    1
# 1308    1
# Length: 1309, dtype: int8
