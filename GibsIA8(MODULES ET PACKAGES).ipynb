# %% [markdown]
# # **Module des Math**

# %%
import math
import random
import statistics
import os
import glob

# %%
print(math.cos(2*math.pi))
print(math.factorial(5))
# Out:
# 1.0
# 120

# %%
statistics.mean(random.sample(range(100),10))
# Out:
# 57

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# # **Exercuse avec resolution**

# %%
filenames = glob.glob('*.txt')
d = {}
for file in filenames:
  with open(file, 'r') as f:
    d[file] = f.read().splitlines()
  
print(d)
